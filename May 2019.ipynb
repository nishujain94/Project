# %% [markdown]
# ## Data for the month of May 2019
# ## Exploratory Data Analysis and perdiction using simple sklearn models are being done
# ### Various Libraries are being imported such as Numpy, Pandas, Matplotlib and Seaborn to extract statistical parameters

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set
# Out:
# <function seaborn.rcmod.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)>

# %% [markdown]
# ### *.JSOLN* files are being imported from the system

# %%
df_1 = pd.read_json('2019-05-01.jsonl', lines = True)
df_2 = pd.read_json('2019-05-02.jsonl', lines = True)
df_3 = pd.read_json('2019-05-03.jsonl', lines = True)
df_4 = pd.read_json('2019-05-04.jsonl', lines = True)
df_5 = pd.read_json('2019-05-05.jsonl', lines = True)
df_6 = pd.read_json('2019-05-06.jsonl', lines = True)
df_7 = pd.read_json('2019-05-07.jsonl', lines = True)
df_8 = pd.read_json('2019-05-08.jsonl', lines = True)
df_9 = pd.read_json('2019-05-09.jsonl', lines = True)
df_10 = pd.read_json('2019-05-10.jsonl', lines = True)
df_11 = pd.read_json('2019-05-11.jsonl', lines = True)
df_12 = pd.read_json('2019-05-12.jsonl', lines = True)
df_13 = pd.read_json('2019-05-13.jsonl', lines = True)
df_14 = pd.read_json('2019-05-14.jsonl', lines = True)
df_15 = pd.read_json('2019-05-15.jsonl', lines = True)
df_16 = pd.read_json('2019-05-16.jsonl', lines = True)
df_17 = pd.read_json('2019-05-17.jsonl', lines = True)
df_18 = pd.read_json('2019-05-18.jsonl', lines = True)
df_19 = pd.read_json('2019-05-19.jsonl', lines = True)
df_20 = pd.read_json('2019-05-20.jsonl', lines = True)
df_21 = pd.read_json('2019-05-21.jsonl', lines = True)
df_22 = pd.read_json('2019-05-22.jsonl', lines = True)
df_23 = pd.read_json('2019-05-23.jsonl', lines = True)
df_24 = pd.read_json('2019-05-24.jsonl', lines = True)
df_25 = pd.read_json('2019-05-25.jsonl', lines = True)
df_26 = pd.read_json('2019-05-26.jsonl', lines = True)
df_27 = pd.read_json('2019-05-27.jsonl', lines = True)
df_28 = pd.read_json('2019-05-28.jsonl', lines = True)
df_29 = pd.read_json('2019-05-29.jsonl', lines = True)
df_30 = pd.read_json('2019-05-30.jsonl', lines = True)
df_31 = pd.read_json('2019-05-31.jsonl', lines = True)

# %% [markdown]
# ### This is to merge all the files into a single .csv file

# %%
df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6, df_7, df_8, df_9, df_10, df_11, df_12, df_13, df_14, df_15, df_16, df_17, df_18, df_19, df_20, df_21, df_22, df_23, df_24, df_25, df_26, df_27, df_28, df_29, df_30, df_31], ignore_index = True, sort = True)
df.to_csv
df.head()
# Out:
#   provider                        schema                               spec  \
# 0   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 1   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 2   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 3   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 4   GitHub  binderhub.jupyter.org/launch  jupyterlab/jupyterlab-demo/master
#
#     status           timestamp  version
# 0  success 2019-05-01 00:00:00        2
# 1  success 2019-05-01 00:00:00        2
# 2  success 2019-05-01 00:00:00        2
# 3  success 2019-05-01 00:00:00        2
# 4  success 2019-05-01 00:01:00        2

# %% [markdown]
# ### df has *409083* values. None of the columns of df has missing values. The data set has information about the courses undertaken by the users in the month of May, 2019. It has the details of the *provider, course name* and the *timestamp*.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409083 entries, 0 to 409082
# Data columns (total 6 columns):
# provider     409083 non-null object
# schema       409083 non-null object
# spec         409083 non-null object
# status       409083 non-null object
# timestamp    409083 non-null datetime64[ns]
# version      409083 non-null int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 18.7+ MB

# %% [markdown]
# ### Total no. of unique projects undertaken are *6180*.

# %%
df.spec.nunique()
# Out:
# 6180

# %% [markdown]
# ### Finding the most popular project/course. It seems *iPython* course was done *183362* times followed by *Demo of Jupyter Lab* with *34704* entries.

# %%
most_popular_projects = df.groupby(['spec'])['spec'].count()
most_popular_projects.nlargest(10)
# Out:
# spec
# ipython/ipython-in-depth/master              183362
# jupyterlab/jupyterlab-demo/master             34704
# DS-100/textbook/master                        21773
# ines/spacy-io-binder/live                     18498
# bokeh/bokeh-notebooks/master                   8916
# ines/spacy-course/binder                       6108
# binder-examples/r/master                       5703
# binder-examples/requirements/master            5402
# rationalmatter/juno-demo-notebooks/master      5153
# QuantStack/xeus-cling/stable                   4512
# Name: spec, dtype: int64

# %% [markdown]
# ### Finding the different provider for the courses.

# %%
df['provider'].unique()
# Out:
# array(['GitHub', 'GitLab', 'Git', 'Gist'], dtype=object)

# %% [markdown]
# ### No. of projects done from a particular source?

# %%
source = df.groupby(['provider', 'spec'])['spec'].count()
source.head()
# Out:
# provider  spec
# Gist      AllenDowney/3e0ee50e828cb3a4bc2a720797bb303c/master       1
#           AustinRochford/505e6a3647c57dbe4bd55a4c311a2a95/master    2
#           AustinRochford/62c283a3f0fae90b5e39/master                1
#           BadreeshShetty/bf9cb1dced8263ef997bcb2c3926569b/master    3
#           BenLangmead/6513059/master                                1
# Name: spec, dtype: int64

# %% [markdown]
# ### *GitHub* seems to be the most common provider with *404286* entries. *Git* being the least used.

# %%
popular_source = df.groupby(['provider'])['provider'].count()
popular_source
df_source = pd.DataFrame(popular_source)
df_source
# Out:
#           provider
# provider
# Gist          2239
# Git            579
# GitHub      404286
# GitLab        1979

# %% [markdown]
# ### Distribution of sources/provider

# %%
# data visualization using matplotlib bar graph for the no. of projects from different sources
plt.bar(df_source.index, df_source['provider'], color = 'g')
plt.yscale('log')
plt.title('Distribution of Sources')
plt.xlabel('Source Name')
plt.ylabel('Projects Undertaken (log scale)')
# Out:
# Text(0,0.5,'Projects Undertaken (log scale)')

# %% [markdown]
# ### For in depth analysis, timestamp is being split

# %%
# splitting timestamp into date and time in different columns
df['new_date'] = [d.date() for d in df['timestamp']]
df['new_time'] = [d.time() for d in df['timestamp']]
df.head()
# Out:
#   provider                        schema                               spec  \
# 0   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 1   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 2   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 3   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 4   GitHub  binderhub.jupyter.org/launch  jupyterlab/jupyterlab-demo/master
#
#     status           timestamp  version    new_date  new_time
# 0  success 2019-05-01 00:00:00        2  2019-05-01  00:00:00
# 1  success 2019-05-01 00:00:00        2  2019-05-01  00:00:00
# 2  success 2019-05-01 00:00:00        2  2019-05-01  00:00:00
# 3  success 2019-05-01 00:00:00        2  2019-05-01  00:00:00
# 4  success 2019-05-01 00:01:00        2  2019-05-01  00:01:00

# %% [markdown]
# ### Maximum number of projects were done on *22nd of May, 2019*

# %%
# top 5 days when the maximum no. of projects were done
most_popular_date = df.groupby(['new_date'])['new_date'].count()
most_popular_date.nlargest()
# Out:
# new_date
# 2019-05-22    18627
# 2019-05-08    17393
# 2019-05-14    17309
# 2019-05-09    16657
# 2019-05-13    16635
# Name: new_date, dtype: int64

# %% [markdown]
# ### Average No. of projects done everyday is 13196!!

# %%
df_date = pd.DataFrame(most_popular_date)
df_date.mean()
# Out:
# new_date    13196.225806
# dtype: float64

# %% [markdown]
# ### The most common time when any particular project is started is in between 1300 hrs and 1500 hrs

# %%
# most common time when the projects start
most_popular_time = df.groupby(['new_time'])['new_time'].count()
most_popular_time.nlargest(5)
# Out:
# new_time
# 14:50:00    497
# 13:41:00    481
# 14:40:00    479
# 09:30:00    477
# 13:42:00    477
# Name: new_time, dtype: int64

# %% [markdown]
# ### Average No. of projects undertaken every minute on a particular day is 9!!

# %%
df_time = pd.DataFrame(most_popular_time)
print(df_time.mean()/31)
# Out:
# new_time    284.085417
# dtype: float64
# new_time    9.164046
# dtype: float64

# %%
# splitting day and time further into year, month, date; hour, minute and second
df['time_str'] = df['new_time'].astype(str)
df['date_str'] = df['new_date'].astype(str)
df[['hour', 'minute', 'seconds']] = df.time_str.str.split(':', expand = True).astype(float)
df[['year', 'month', 'date']] = df.date_str.str.split('-', expand = True).astype(float)
df.head()
# Out:
#   provider                        schema                               spec  \
# 0   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 1   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 2   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 3   GitHub  binderhub.jupyter.org/launch    ipython/ipython-in-depth/master
# 4   GitHub  binderhub.jupyter.org/launch  jupyterlab/jupyterlab-demo/master
#
#     status           timestamp  version    new_date  new_time  time_str  \
# 0  success 2019-05-01 00:00:00        2  2019-05-01  00:00:00  00:00:00
# 1  success 2019-05-01 00:00:00        2  2019-05-01  00:00:00  00:00:00
# 2  success 2019-05-01 00:00:00        2  2019-05-01  00:00:00  00:00:00
# 3  success 2019-05-01 00:00:00        2  2019-05-01  00:00:00  00:00:00
# 4  success 2019-05-01 00:01:00        2  2019-05-01  00:01:00  00:01:00
#
#      date_str  hour  minute  seconds    year  month  date
# 0  2019-05-01   0.0     0.0      0.0  2019.0    5.0   1.0
# 1  2019-05-01   0.0     0.0      0.0  2019.0    5.0   1.0
# 2  2019-05-01   0.0     0.0      0.0  2019.0    5.0   1.0
# 3  2019-05-01   0.0     0.0      0.0  2019.0    5.0   1.0
# 4  2019-05-01   0.0     1.0      0.0  2019.0    5.0   1.0

# %% [markdown]
# ### Finding the most common hour to start a project! 1300 hours

# %%
# most common hour when the project starts
most_popular_hour = df.groupby(['hour'])['hour'].count()
most_popular_hour.nlargest(5)
# Out:
# hour
# 13.0    24603
# 14.0    24324
# 12.0    22764
# 9.0     22713
# 15.0    22112
# Name: hour, dtype: int64

# %% [markdown]
# ### Average No. of Projects done every hour is around 550!

# %%
df_hour = pd.DataFrame(most_popular_hour)
df_hour.mean()/31
# Out:
# hour    549.842742
# dtype: float64

# %% [markdown]
# ### Representing the No. of Projects undertaken in a particular hour across the whole month

# %%
# data visualisation on the basis of the hour in which the project was done
df.hist(column = 'hour', bins = 24, rwidth = 0.9, color = 'y')
plt.xlabel('Time (in hours)')
plt.ylabel('No. of projects undertaken')
plt.title('Distribution on the basis of time')
# Out:
# Text(0.5,1,'Distribution on the basis of time')

# %% [markdown]
# ### Maximum projects were done in between 1300 hrs and 1400 hrs

# %%
# most common hour
df['hour'].mode()
# Out:
# 0    13.0
# dtype: float64

# %% [markdown]
# ### The maximum traffic was on 22nd of May, 2019

# %%
# most popular date of May, 2019
df['date'].mode()
# Out:
# 0    22.0
# dtype: float64

# %% [markdown]
# ### Representing the No. of Projects undertaken on a particular date across the whole month

# %%
#data visualisation on the basis of the date of May, 2019
df.hist(column = 'date', bins = 30, rwidth = 0.9, color = 'y')
plt.xlabel('Date')
plt.ylabel('No. of Projects undertaken')
plt.title('Distribution on the basis of date')
# Out:
# Text(0.5,1,'Distribution on the basis of date')

# %% [markdown]
# ### Another way to represent the no. of a projects using Seaborn Library

# %%
# using seaborn tools to visualise the data on the basis of time of the day
sns.distplot(df.hour)

# %%
# using seaborn tools to visualise the data on the basis of the date of the month
sns.distplot(df.date)

# %% [markdown]
# ### To extract statistical parameters from the data, we need to change string values of the provider and spec into the integer value.

# %%
pro = df['provider'].tolist()
s = pd.Series(pro)
labels, levels = pd.factorize(s)
df1 = pd.DataFrame({'provider':(labels)})
df.pop('provider')
df=df.join(df1)

# %%
course=df['spec'].tolist()
s = pd.Series(course)
labels, levels = pd.factorize(s)
df1 = pd.DataFrame({'spec':(labels)})
df.pop('spec')
df=df.join(df1)

# %% [markdown]
# ### There is not much variation in the distribution across a particular date and hour

# %%
pd.crosstab(df.hour, df.date, margins = True).style.background_gradient(cmap='autumn_r')
# Out:
# <style  type="text/css" >
#     #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col0 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col1 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col2 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col3 {
#             background-color:  #fffd00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col4 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col5 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col6 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col7 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col8 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col9 {
#             background-color:  #fffc00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col10 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col11 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col12 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col13 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col14 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col15 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col16 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col17 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col18 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col19 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col20 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col21 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col22 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col23 {
#             background-color:  #fffa00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col24 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col25 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col26 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col27 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col28 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col29 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col30 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row0_col31 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col0 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col1 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col2 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col3 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col4 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col5 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col6 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col7 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col8 {
#             background-color:  #fffd00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col9 {
#             background-color:  #fffc00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col10 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col11 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col12 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col13 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col14 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col15 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col16 {
#             background-color:  #fffc00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col17 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col18 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col19 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col20 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col21 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col22 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col23 {
#             background-color:  #fffc00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col24 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col25 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col26 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col27 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col28 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col29 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col30 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row1_col31 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col0 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col1 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col2 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col3 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col4 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col5 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col6 {
#             background-color:  #fffd00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col7 {
#             background-color:  #ffff00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col8 {
#             background-color:  #fffe00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col9 {
#             background-color:  #fffc00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col10 {
#             background-color:  #fffd00;
#         }    #T_9b05ac06_b450_11e9_a9fd_e46520c44808row2_col11 {
#             background-color:  #fffd00;
#         }    #T_9b05ac06_b450_11e

# %% [markdown]
# ## Test using simple Decision Tree and Random Forest Model from sklearn model

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from math import sqrt

# %% [markdown]
# ### First we define the parameters to predict the test case, the hour is being predicted keeping spec, provider and date as features.

# %%
y = df.hour
features = ['spec', 'provider', 'date']
X = df[features]
features_1 = ['spec', 'provider', 'date', 'hour']
Y = df[features_1]

# %% [markdown]
# ### We apply the test/train split to get a first overview of the model performance. We have predicted the hour in which the project from a test data will be started.

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1)
df_model = RandomForestRegressor(random_state = 1)
df_model.fit(train_X, train_y)
df_predictions = df_model.predict(val_X)
print(df_predictions)
# Out:
# [ 9.33153356  5.15238095 11.48847717 ... 10.41370788 19.045
#  11.897042  ]

# %% [markdown]
# ### The accuracy of the model is being tested by calculating Mean Absolute Error which is 4.72 and RMSE of 5.82.

# %%
df_mae = mean_absolute_error(df_predictions, val_y)
print(df_mae)
df_mse = mean_squared_error(df_predictions, val_y)
print(df_mse)
rmse = sqrt(df_mse)
print(rmse)
# Out:
# 4.727974998281183
# 33.988401476446334
# 5.829957244821469

# %% [markdown]
# ### There is not much correlation between the project undertaken and the various parameters of the data.

# %%
print(Y.corr())
# Out:
#               spec  provider      date      hour
# spec      1.000000  0.098441  0.146765  0.042911
# provider  0.098441  1.000000 -0.048344  0.011894
# date      0.146765 -0.048344  1.000000 -0.023311
# hour      0.042911  0.011894 -0.023311  1.000000

# %% [markdown]
# ### Decision Tree Model also predicted the time with the Mean Absolute Error and RMSE similar to Random Forest Model.

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 1)
df_DT_model = DecisionTreeRegressor(random_state = 1)
df_DT_model.fit(train_X, train_y)
df_DT_predictions = df_DT_model.predict(val_X)
print(df_DT_predictions)
# Out:
# [ 9.23809524  5.         11.49863636 ... 10.40383704 20.
#  11.88690023]

# %%
df_DT_mae = mean_absolute_error(df_DT_predictions, val_y)
print(df_DT_mae)
df_DT_mse = mean_squared_error(df_DT_predictions, val_y)
print(df_DT_mse)
rmse_DT = sqrt(df_DT_mse)
print(rmse_DT)
# Out:
# 4.747081046709708
# 34.65872756782684
# 5.887166344501133

# %% [markdown]
# ### Summary of the Data:

# %% [markdown]
# 1. Most Common *Provider* - **GitHub**
# 2. Most Common *Project* - **ipython/ipython-in-depth/master**
# 3. Average No. of projects done everyday- **13196**
# 4. Average No. of projects done every hour in a day is **550**
# 5. The best time for a source to provide a course to have the maximum users is between **1300 hours to 1400 hours**
# 6. The best time to start a course can be predicted with the Random Forest Regressor with **root mean square error of 5.88**
